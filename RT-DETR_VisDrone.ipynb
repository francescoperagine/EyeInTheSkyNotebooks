# %% [markdown]
# <a href="https://colab.research.google.com/github/francescoperagine/EyeInTheSkyNotebooks/blob/main/RT-DETR_VisDrone.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# !pip install loguru==0.7.3 \
             tqdm==4.67.1 \
             typer==0.15.1 \
             ultralytics==8.3.68 \
             wandb==0.19.6

# %%
import torch
from loguru import logger
import wandb
from google.colab import userdata, files
from ultralytics import RTDETR, checks, settings
import time

# %%
model_name = "rtdetr-l.pt"
api_key = userdata.get("WANDB_API_KEY")

project_name = "EyeInTheSky"
experiment_name = "RT-DETR_VisDrone"
dataset_name = "VisDrone"

# %%
try:
    device =  0 if torch.cuda.is_available() else "cpu"
except Exception as e:
    print(f"Error setting device: {e}")
print(f"Device: {device}")

# %%
settings.update({"wandb": True})

# %%
wandb.login(key=api_key)

# %%
logger.info("Performing training for model...")
logger.info(checks())

# %%
model = RTDETR(model_name)

# %%
model.info()

# %%
for k, v in model.named_parameters():
    print(k)

# %%
results = model.train(data=f"{dataset_name}.yaml",
    workers=8,
    batch=16,
    epochs=100,
    half=True,
    augment=False,
    cache=False,
    amp=True,
    imgsz=640,
    device=device,
    patience=5,
    project=project_name,
    name=experiment_name,
    seed=42,
    plots=True,
    save=True,
    save_period=5
  )

# %%
timestamp = time.strftime("%Y%m%d_%H%M%S")  # Get current time in YYYYMMDD_HHMMSS format
zip_filename = f"/content/{project_name}_{timestamp}.zip"

# !zip -r "$zip_filename" /content/"$project_name"

# %%
files.download(zip_filename)
